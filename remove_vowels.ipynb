# %% [markdown]
# <a href="https://colab.research.google.com/github/eloster1331/python_projects/blob/main/remove_vowels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def remove_vowels(input_string):
    vowels = "aeiouAEIOU"
    result = ""
    for char in input_string:
        if char not in vowels:
            result += char
    return result

my_result = remove_vowels("cOCEaZyFcBuPqdGxhUeuFbtWVXQjgsZdFUyoaxBSVmeTGRjdnarQEpozeuBWQgTWjANMFGMqoQmJggqMNytOhNwkoOoWzqvVhkSM")

print(my_result)
# Out:
# cCZyFcBPqdGxhFbtWVXQjgsZdFyxBSVmTGRjdnrQpzBWQgTWjNMFGMqQmJggqMNythNwkWzqvVhkSM
